# %% [markdown]
# ### Part One

# %%
# load the urllib.request module
import urllib.request
# load pandas
import pandas as pd
# read json file
json = pd.read_json("https://raw.githubusercontent.com/sunpark92/DAV-5400/master/favbook.json")
# print json
json
# Out:
#        name                      Title                           Authors  \
# 0  favbooks  Conversation with friends                      Sally Rooney
# 1  favbooks               Harry Potter                     J. K. Rowling
# 2  favbooks                     Wonder  R. J. Palacio and Brian Kilmeade
#
#   Language  Published
# 0  English       2018
# 1  English       1999
# 2   French       2019

# %% [markdown]
# ### Part Two

# %%
# import library
import requests
# store url
url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?api-key=sj0J71sh8zGSnv39wQgVbchEJ94hDmJp"
article = requests.get(url)
# check if connect success
article
# Out:
# <Response [200]>

# %%
article.text
# Out:
# '{"status":"OK","copyright":"Copyright (c) 2019 The New York Times Company. All Rights Reserved.","response":{"docs":[{"abstract":"Under-fire Everton manager Marco Silva has said his side\'s battling performance in Sunday\'s 2-1 defeat to Leicester City showed he had not lost the backing of the dressing room.","web_url":"https://www.nytimes.com/reuters/2019/12/01/sports/soccer/01reuters-soccer-england-lei-eve.html","snippet":"Under-fire Everton manager Marco Silva has said his side\'s battling performance in Sunday\'s 2-1 defeat to Leicester City showed he had not lost the backing of the dressing room.","lead_paragraph":"(Reuters) - Under-fire Everton manager Marco Silva has said his side\'s battling performance in Sunday\'s 2-1 defeat to Leicester City showed he had not lost the backing of the dressing room.","source":"Reuters","multimedia":[],"headline":{"main":"Everton\'s Commitment Levels Cannot Be Questioned, Says Silva","kicker":null,"content_kicker":null,"print_headline":"Ever
# ...

# %%
# now convert the 'article' object's JSON content into a dict of 
# native Python objects
data = article.json()
type(data)
# Out:
# dict

# %%
# check the content of the dict
data
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2019 The New York Times Company. All Rights Reserved.',
#  'response': {'docs': [{'abstract': "Under-fire Everton manager Marco Silva has said his side's battling performance in Sunday's 2-1 defeat to Leicester City showed he had not lost the backing of the dressing room.",
#     'web_url': 'https://www.nytimes.com/reuters/2019/12/01/sports/soccer/01reuters-soccer-england-lei-eve.html',
#     'snippet': "Under-fire Everton manager Marco Silva has said his side's battling performance in Sunday's 2-1 defeat to Leicester City showed he had not lost the backing of the dressing room.",
#     'lead_paragraph': "(Reuters) - Under-fire Everton manager Marco Silva has said his side's battling performance in Sunday's 2-1 defeat to Leicester City showed he had not lost the backing of the dressing room.",
#     'source': 'Reuters',
#     'multimedia': [],
#     'headline': {'main': "Everton's Commitment Levels Cannot Be Questioned, Says Silva",
# ...

# %%
# Extracted the content started from response 
results = data['response']
results
# Out:
# {'docs': [{'abstract': "Under-fire Everton manager Marco Silva has said his side's battling performance in Sunday's 2-1 defeat to Leicester City showed he had not lost the backing of the dressing room.",
#    'web_url': 'https://www.nytimes.com/reuters/2019/12/01/sports/soccer/01reuters-soccer-england-lei-eve.html',
#    'snippet': "Under-fire Everton manager Marco Silva has said his side's battling performance in Sunday's 2-1 defeat to Leicester City showed he had not lost the backing of the dressing room.",
#    'lead_paragraph': "(Reuters) - Under-fire Everton manager Marco Silva has said his side's battling performance in Sunday's 2-1 defeat to Leicester City showed he had not lost the backing of the dressing room.",
#    'source': 'Reuters',
#    'multimedia': [],
#    'headline': {'main': "Everton's Commitment Levels Cannot Be Questioned, Says Silva",
#     'kicker': None,
#     'content_kicker': None,
# ...

# %%
NYT = pd.DataFrame(results, columns=['web_url', 'snippet',
                                   'lead_paragraph', 'print_page','pub_date','document_type','type_of_material',
                                   '_id','word_count','score'])

# %%
NYT
# Out:
# Empty DataFrame
# Columns: [web_url, snippet, lead_paragraph, print_page, pub_date, document_type, type_of_material, _id, word_count, score]
# Index: []
